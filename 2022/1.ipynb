# %% [markdown]
# # Part 1

# %%
with open("assets/1.txt") as elves:
    print(max([eval(pack) for pack in [elf.replace("\n", "+") for elf in elves.read().split("\n\n")[:-1:]]]))
# Out:
# 72017

# %% [markdown]
# # Part 2

# %%
with open("assets/1.txt") as elves:
    print(sum(sorted([eval(pack) for pack in [elf.replace("\n", "+") for elf in elves.read().split("\n\n")[:-1:]]])[-3::]))
# Out:
# 212520
