# %% [markdown]
# # Part 1

# %%
with open("assets/1.txt") as elf: print(sorted([eval(calories) for calories in [food_item.replace("\n", "+") for food_item in elf.read().split("\n\n")] if calories[-1] != "+"])[-1])
# Out:
# Running cells with 'c:\Users\Andre\AppData\Local\Programs\Python\Python39\python.exe' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/Andre/AppData/Local/Programs/Python/Python39/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# # Part 2

# %%
with open("assets/1.txt") as elf: print(sum(sorted([eval(calories) for calories in [food_item.replace("\n", "+") for food_item in elf.read().split("\n\n")] if calories[-1] != "+"])[-3::]))
# Out:
# Running cells with 'c:\Users\Andre\AppData\Local\Programs\Python\Python39\python.exe' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/Andre/AppData/Local/Programs/Python/Python39/python.exe -m pip install ipykernel -U --user --force-reinstall'
