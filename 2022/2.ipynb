# %% [markdown]
# # Part 1

# %%
with open("assets/2.txt") as file:
    print(sum([{"AX": 4, "AY": 8, "AZ": 3, "BX": 1, "BY": 5, "BZ": 9, "CX": 7, "CY": 2, "CZ": 6}[i] for i in file.read().replace(" ", "").split("\n")[:-1:]]))
# Out:
# 12679

# %% [markdown]
# # Part 2

# %%
with open("assets/2.txt") as file:
    print(sum([{"AX": 3, "AY": 4, "AZ": 8, "BX": 1, "BY": 5, "BZ": 9, "CX": 2, "CY": 6, "CZ": 7}[i] for i in file.read().replace(" ", "").split("\n")[:-1:]]))
# Out:
# 14470
